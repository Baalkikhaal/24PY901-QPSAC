# %% [markdown]
# # Quantum principles
#
# Idea map
#
# - [Hilbert space](./qp_hilbert_space.ipynb)
# - Postulates of quantum mechanics
#    - [Wave ket postulate](./qp_wave_ket_postulate.ipynb)
#    - [operator postulate](./qp_operator_postulate.ipynb)
#    - [Time evolution postulate](./qp_time_evolution_postulate.ipynb)
#    - [Measurement postulate](./qp_measurement_postulate.ipynb)
# - [Commutator algebra](./qp_commutator_algebra.ipynb)
# - [Pauli's spin matrices](./qp_spin_matrices.ipynb)
