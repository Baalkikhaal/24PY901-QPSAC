# %% [markdown]
# # Quantum Computing
#
# Idea map
#
# - [Classical computation](./qc_classical_computation.ipynb)
# - [Quantum computation](./qc_quantum_computation.ipynb)
# - [Classical computation on a quantum computer](./qc_q_simulator_of_classical_computer.ipynb)
# - [Quantum computation on a classical computer](./qc_c_simulator_of_quantum_computer.ipynb)
