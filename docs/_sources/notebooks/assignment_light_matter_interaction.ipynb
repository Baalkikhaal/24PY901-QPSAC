# %% [markdown]
# # Assignment on light-matter interaction
#
# In this assignment, let us focus on the nature of light and its interaction with matter.
#
# [Download assignment on light-matter interaction](./pdfs/Assignment_M1U1_1.pdf)
