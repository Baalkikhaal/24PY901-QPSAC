# %% [markdown]
# # Pauli spin matrices
#
# σx = [[0,1],[1,0]]
# σy = [[0,-i],[i,0]]
# σz = [[1,0],[0,-1]]

# %%
import numpy as np

sx = np.array([[0,1],[1,0]])
sy = np.array([[0,-1j],[1j,0]])
sz = np.array([[1,0],[0,-1]])

# %% [markdown]
# # Algebra
#
# [σx, σy] = 2iσz

# %%
psi = np.array([1,0])  # spin up

# %% [markdown]
# # Exercises
#
# 1. Verify σx² = I
# 2. Compute eigenvalues of σy
# 3. Show commutation relations
