# %% [markdown]
# # Light matter interaction
#
# This is the introductory unit of this course. Here we will study the basics of light and matter interaction.
#
# - [Light and matter interaction](./light_matter_interaction.ipynb)
# - [Atomic spectra](./lm_atomic_spectra.ipynb)
# - [Bohr's quantization rule](./lm_bohr_quantization_rule.ipynb)
# - Properties of electromagnetic wave
#     - [Coherence](./lm_coherence.ipynb)
#     - [Polarization](./lm_polarization.ipynb)
# - [Interference](./lm_interference.ipynb)
