# %% [markdown]
# # Quantum Principles, Structures and Computing
#
# Course Idea map
# - [Light and matter interaction](./light_matter_interaction.ipynb)
# - [Quantum Principles](./q_principles.ipynb)
# - [Quantum Structures](./q_structures.ipynb)
# - [Quantum Computing](./q_computing.ipynb)
# - [Qiskit](./qiskit.ipynb)

# %% [markdown]
# # Assignments
#
# Quantum principles
#
# - [Nature of light-matter interaction](./assignment_light_matter_interaction.ipynb)
# - [Physics of smartphone](./assignment_physics_of_smartphone.ipynb)
# - [Formulation of linear systems](./assignment_linear_system_formulation.ipynb)
# - [Postulates of quantum mechanics](./assignment_postulates_of_quantum_mechanics.ipynb)
#
# Quantum structures
#
# - [Gaussian wavepacket in free space](./assignment_gaussian_wave_packet.ipynb)
# - [TISE of quantum structures](./assignment_tise_of_quantum_structure.ipynb)
#
# Quantum computing
#
# - [Simulation of one qubit circuits](./assignment_single_qubit_circuits.ipynb)
# - [Simulation of multiple qubit circuits](./assignment_multiple_qubit_circuits.ipynb)

# %% [markdown]
# # Home works
#
# - [Waveket representation of polarization states](./hw_waveket_representation.ipynb)
# - [Eigenvalues and eigenvectors of $\tilde{S}_x$](./hw_eigenvalues_and_eigenkets.ipynb)
# - [Unitary transformation](./hw_unitary_transformation.ipynb)
# - [Dirac notation of Hermitian operator](./hw_dirac_notation_operator.ipynb)
# - [Hamiltonian in matrix and Dirac notation](./hw_hamiltonian_notations.ipynb)
# - [Differentiation and Integration of functions](./hw_differentiation_integration.ipynb)
# - [Traveling vs standing waves](./hw_traveling_standing_waves.ipynb)
# - [Properties of anti-Hermitian operators](./hw_anti_hermitian_operators.ipynb)
