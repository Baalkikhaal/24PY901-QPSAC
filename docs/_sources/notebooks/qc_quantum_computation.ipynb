# %% [markdown]
# # Quantum computation
#
# Circuit model of quantum computation
#
# - Distinguishable computational basis states
# - Universal set of quantum gates
# - Preparation of initial state
# - Quantum measurement
# - Quantum algorithm

# %% [markdown]
# # Quantum gates
#
# - X
# - Y
# - Z
# - H
# - CNOT
# - Toffoli
#
# CNOT is a generalization of classical XOR gate

# %% [markdown]
# # Universal set of quantum logic gates
#
# - Any multiple qubit gate can be composed of CNOT plus single qubit gates
# - Toffoli gate based quantum computation
