# %% [markdown]
# # Quantum structures
#
# Idea map
#
# - [TISE](./qs_Time_Independent_Schrodinger_equation.ipynb)
# - [Finite difference method](./qs_finite_difference_method.ipynb)
# - [Numerical solution to TISE](./qs_numerical_solution_to_TISE.ipynb)
# - [Quantum structure leading to free particle](./qs_Gaussian_wave_packet.ipynb)
# - [Quantum structures leading to scattering particle](./qs_scattering_states.ipynb)
# - [Quantum structures leading to bound particle](./qs_bound_states.ipynb)
# - [Quantum confinement](./qs_confinement.ipynb)
