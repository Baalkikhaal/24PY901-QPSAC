# %% [markdown]
# # Qiskit
#
# Qiskit is a open source Python package developed by IBM for simulating a quantum computation on a classical computer.

# %% [markdown]
# - [Install miniconda](./pdfs/install_miniconda.pdf)
# - Qiskit environment
#    - [Setup qiskit environment](./pdfs/qiskit_environment_setup.pdf)
#    - [Test qiskit setup](./test_qiskit.ipynb)

# %% [markdown]
# # Qiskit objects
#
# - [QuantumCircuit](./qiskit_QuantumCircuit.ipynb)
# - [Statevector](./qiskit_Statevector.ipynb)
# - [Operator](./qiskit_Operator.ipynb)
# - [Registers](./qiskit_Registers.ipynb)
# - [Visualization tools](./qiskit_visualization.ipynb)
