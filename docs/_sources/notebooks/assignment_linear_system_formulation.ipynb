# %% [markdown]
# # Assignment on linear system formulation
#
# In this notebook, let us look at how to "linearize" systems from various disciplines.
#
# [Download assignment on linear system formulation](./pdfs/Assignment_M1U2_3.pdf)

# %% [markdown]
# # Solutions
#
# - [Download solution to assignment on linear system formulation](./pdfs/Solution_M1U2_A3.pdf)
