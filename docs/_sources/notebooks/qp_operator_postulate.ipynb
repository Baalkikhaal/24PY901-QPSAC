# %% [markdown]
# # Operator postulate
#
# Every observable corresponds to a linear Hermitian operator.

# %%
import numpy as np

sigma_z = np.array([[1,0],[0,-1]])
sigma_z
# Out:
# array([[ 1,  0],
#        [ 0, -1]])

# %% [markdown]
# # Eigenvalue equation
#
# A|ψ⟩ = a|ψ⟩

# %% [markdown]
# # Exercises
#
# 1. Find eigenvalues of [[0,1],[1,0]]
# 2. Show Hermitian condition A = A†
