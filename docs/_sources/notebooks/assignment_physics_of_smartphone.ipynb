# %% [markdown]
# # Assignment on physics of smartphone
#
# In this assignment, let us focus on quantum mechanics principles used in various technologies of smartphone.
#
# [Download assignment on physics of smartphone](./pdfs/Assignment_M1U1_2.pdf)

# %% [markdown]
# # Solutions
#
# - [Download solution to assignment on physics of smartphone](./pdfs/Solution_M1U1_A2.pdf)
# - [Download detailed solution to assignment on physics of smartphone](./pdfs/Solution_M1U1_A2_detailed.pdf)
