# %% [markdown]
# # Interference
#
# Interference is a result of principle of superposition.
# Since the waves add up according to the rules of vector algebra, we have two limiting cases
#
# - constructive interference
# - destructive interference
#
# The other situations fall in between these cases
#
# Let us study the concept of interference in the famous Young's double slit experiment

# %% [markdown]
# # Young's double slit experiment
#
# **#TODO** work on young's double slit experiment content
