# %% [markdown]
# # Assignment on Gaussian wavepacket in free space
#
# In this notebook, let us study the time evolution of Gaussian wavepacket in free space.
#
# [Download assignment on Gaussian wavepacket](./pdfs/Assignment_M2U1_5.pdf)
