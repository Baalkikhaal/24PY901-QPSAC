# %% [markdown]
# # Bohr's quantization rule
#
# The quantization rule states that
#
# the angular momentum of an electron can take integral multiples of reduced Planck's constant.
#
# $$
# mvr = n \hbar
# $$

# %% [markdown]
# # Energy levels of hydrogen atom
#
# Using Bohr's quantization rule and the Coulomb's law of interacting charges, let us derive the energy levels of the hydrogen atom
