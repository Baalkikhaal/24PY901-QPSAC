# %% [markdown]
# # Assignment on postulates of quantum mechanics
#
# In this notebook, let us explore the postulates of quantum mechanics.
#
# [Download assignment on postulates of quantum mechanics](./pdfs/Assignment_M1U2_4.pdf)

# %% [markdown]
# # Solutions
#
# - [Download solution to assignment on postulates of quantum mechanics](./pdfs/Solution_M1U2_A4.pdf)
