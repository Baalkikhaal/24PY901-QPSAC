# %% [markdown]
# # Commutator algebra
#
# [A, B] = AB - BA

# %% [markdown]
# # Canonical commutator relation
#
# [x, p] = iħ

# %%
import numpy as np

A = np.array([[0,1],[1,0]])
B = np.array([[1,0],[0,-1]])

comm = A @ B - B @ A
comm
# Out:
# array([[ 0, -2],
#        [ 2,  0]])

# %% [markdown]
# 1. Compute [σx, σy]
# 2. Verify non-commutativity
