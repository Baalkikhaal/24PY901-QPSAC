# %% [markdown]
# # Assignment on single qubit circuits
#
# Quantum computation is based on transformation of wavekets by quantum gates.
#
# In this assignment, let us focus on single qubit circuit that consist of singe quantum bit and single quantum gate.
#
# **#TODO** Needs to be designed.
