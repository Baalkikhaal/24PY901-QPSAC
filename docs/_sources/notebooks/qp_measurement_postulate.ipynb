# %% [markdown]
# # Measurement postulate
#
# Measurement outcomes = eigenvalues of operator

# %% [markdown]
# # Probability
#
# P(a) = |⟨a|ψ⟩|²

# %% [markdown]
# # Collapse
#
# After measurement → system collapses to eigenstate

# %%
import numpy as np
psi = np.array([1/np.sqrt(2), 1/np.sqrt(2)])
basis_0 = np.array([1,0])

prob = abs(np.vdot(basis_0, psi))**2
prob
# Out:
# np.float64(0.4999999999999999)

# %% [markdown]
# 1. Compute probability for σz measurement
# 2. What happens after measurement?
